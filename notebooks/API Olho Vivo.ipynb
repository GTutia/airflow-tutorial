# %%
import requests
import pandas as pd

NETWORK_URL = "https://api.citybik.es/v2/networks/bikesampa"

response = requests.get(NETWORK_URL)

if response.status_code == 200:
    data = response.json()
    stations = data["network"]["stations"]
    df_stations = pd.DataFrame(stations)
    display(df_stations.head(10))  # Mostra as 10 primeiras estações
else:
    print("Erro na requisição:", response.status_code)
# Out:
#                                  id                              name  \
# 0  0495af0c779f79ebaa01242df456963d                  204 - Consolação
# 1  05ac42b0b09d9dda95118ee7ff00d5bc               150 - Metrô Paraíso
# 2  07e1bc56a4d45c04055860ae39f9322a         7 - Praça Joaquim Roberto
# 3  086f46ad981708395ea90ca6ae362832  434 - Praça Procópio Ferreira II
# 4  0b509d7429586cacb0776fd8b203d61c            443 - Cardoso Melo III
# 5  0c03fdb27d57954593e6da8f953d697f     14 - Museu da Casa Brasileira
# 6  0d2a3ac5d13a76ec7974e997b3717b0b     519 - Praça Afrodisio Vidigal
# 7  0d4298dc15738906a9ac9f3a70dc21cb                 266 - Méqui Verde
# 8  0e40d986af22d73ed98818286954e46d   517 - Travessa Hélio Pellegrino
# 9  0ecb986a30ea8a70c99bd89d758a1e86      290 - Metrô Marechal Deodoro
#
#     latitude  longitude                          timestamp  free_bikes  \
# 0 -23.556727 -46.664197  2025-08-17T20:00:25.505310+00:00Z           0
# 1 -23.575386 -46.641375  2025-08-17T20:00:25.504968+00:00Z           0
# 2 -23.572544 -46.693681  2025-08-17T20:00:25.503928+00:00Z          10
# 3 -23.599550 -46.690740  2025-08-17T20:00:25.506774+00:00Z           3
# 4 -23.596440 -46.688550  2025-08-17T20:00:25.506569+00:00Z           0
# 5 -23.580880 -46.684709  2025-08-17T20:00:25.503999+00:00Z           8
# 6 -23.577480 -46.640810  2025-08-17T20:00:25.506697+00:00Z           0
# 7 -23.573640 -46.642140  2025-08-17T20:00:25.506850+00:00Z           0
# 8 -23.598740 -46.671440  2025-08-17T20:00:25.506950+00:00Z           2
# 9 -23.533742 -46.657056  2025-08-17T20:00:25.506281+00:00Z          18
#
#    empty_slots                                              extra
# 0           19  {'uid': '204', 'renting': 1, 'returning': 1, '...
# 1           19  {'uid': '150', 'renting': 1, 'returning': 1, '...
# 2            9  {'uid': '7', 'renting': 1, 'returning': 1, 'la...
# 3           12  {'uid': '592', 'renting': 1, 'returning': 1, '...
# 4           15  {'uid': '556', 'renting': 1, 'returning': 1, '...
# 5            9  {'uid': '14', 'renting': 1, 'returning': 1, 'l...
# 6           14  {'uid': '573', 'renting': 1, 'returning': 1, '...
# 7            7  {'uid': '601', 'renting': 1, 'returning': 1, '...
# 8           13  {'uid': '628', 'renting': 1, 'returning': 1, '...
# 9            1  {'uid': '446', 'renting': 1, 'returning': 1, '...

# %%
df_new = pd.DataFrame(data['network']['stations'])

# %%
df_both = df_old.merge(df_new[['id','timestamp','free_bikes','empty_slots']], on = 'id', how = 'left', suffixes = ('_old','_new'))

# %%
key_list = []
for station in data['network']['stations']:
    key_list = key_list + list(data['network']['stations'][0]['extra'].keys())

# %%
key_list = list(set(key_list))

# %%
extra_dict = []
for station in data['network']['stations']:
    for key in data['network']['stations'][0]['extra'].keys():
        if key not in key_list:
            print(f"Station {station['name']} does not have {key}")

# %%
def clean_stations(data):
    stations = []
    for station in data['network']['stations']:
        station_data = {}
        for key in station.keys():
            if key != 'extra':
                station_data[key] = station[key]
            else:
                for extra_key in station['extra'].keys():
                    station_data[extra_key] = station['extra'][extra_key]
        stations.append(station_data)
    
    return pd.DataFrame(stations)

# %%
def get_distances(data):
    supersim_lat = -23.556641
    supersim_lng = -46.681632
    distances = []
    for station in data['network']['stations']:
        lat = station['latitude']
        lng = station['longitude']
        p1 = (lat, lng)
        p2 = (supersim_lat, supersim_lng)
        distance = geodesic(p1, p2).km
        distances.append(distance)
    return distances

# %%
df_stations = clean_stations(data)

# %%
df_stations
# Out:
#                                    id                              name  \
# 0    0495af0c779f79ebaa01242df456963d                  204 - Consolação
# 1    05ac42b0b09d9dda95118ee7ff00d5bc               150 - Metrô Paraíso
# 2    07e1bc56a4d45c04055860ae39f9322a         7 - Praça Joaquim Roberto
# 3    086f46ad981708395ea90ca6ae362832  434 - Praça Procópio Ferreira II
# 4    0b509d7429586cacb0776fd8b203d61c            443 - Cardoso Melo III
# ..                                ...                               ...
# 235  fd5d8d6dcc34499ffa8ca4db591e8e45           317 - R. Leonardo Nunes
# 236  fdb890213c54ad952730bd9fab78a147                  76 - 8° Batalhão
# 237  fe23e24943b116bf2b7bbfe856292ffa        131 - Ibirapuera Portão 06
# 238  ff724047677a832632b2ec87805270c0      215 - E.E. Godofredo Furtado
# 239  ffb465bbe6bcfa90eeb06be01e8e3753        95 - R. Manoel da Nóbrega
#
#       latitude  longitude                          timestamp  free_bikes  \
# 0   -23.556727 -46.664197  2025-08-17T20:00:25.505310+00:00Z           0
# 1   -23.575386 -46.641375  2025-08-17T20:00:25.504968+00:00Z           0
# 2   -23.572544 -46.693681  2025-08-17T20:00:25.503928+00:00Z          10
# 3   -23.599550 -46.690740  2025-08-17T20:00:25.506774+00:00Z           3
# 4   -23.596440 -46.688550  2025-08-17T20:00:25.506569+00:00Z           0
# ..         ...        ...                                ...         ...
# 235 -23.598733 -46.639103  2025-08-17T20:00:25.505845+00:00Z           1
# 236 -23.574298 -46.654040  2025-08-17T20:00:25.504419+00:00Z           2
# 237 -23.593685 -46.660042  2025-08-17T20:00:25.504800+00:00Z          13
# 238 -23.559442 -46.678456  2025-08-17T20:00:25.505348+00:00Z           1
# 239 -23.568159 -46.648978  2025-08-17T20:00:25.504534+00:00Z           0
#
#      empty_slots  uid  renting  returning  ...  post_code has_ebikes ebikes  \
# 0             19  204        1          1  ...   03164200       True      0
# 1             19  150        1          1  ...        NaN       True      0
# 2              9    7        1          1  ...   03164200       True      0
# 3             12  592        1          1  ...  04533-085       True      0
# 4             15  556        1          1  ...  04548-005       True      0
# ..           ...  ...      ...        ...  ...        ...        ...    ...
# 235           14  317        1          1  ...   03164200       True      0
# 236           13   76        1          1  ...   03164200       True      0
# 237            6  131        1          1  ...   03164200       True      0
# 238           14  215        1          1  ...        NaN       True      0
# 239            6   95        1          1  ...   03164200       True      0
#
#      normal_bikes                                payment  payment-terminal  \
# 0               0              [key, transitcard, phone]             False
# 1               0  [key, transitcard, creditcard, phone]              True
# 2              10              [key, transitcard, phone]             False
# 3               3              [key, transitcard, phone]             False
# 4               0              [key, transitcard, phone]             False
# ..            ...                                    ...               ...
# 235             1  [key, transitcard, creditcard, phone]              True
# 236             2  [key, transitcard, creditcard, phone]              True
# 237            13              [key, transitcard, phone]             False
# 238             1  [key, transitcard, creditcard, phone]              True
# 239             0              [key, transitcard, phone]             False
#
#     altitude slots  rental_uris  virtual
# 0     -23.56    19           {}    False
# 1        NaN    19           {}    False
# 2        NaN    19           {}    False
# 3       0.00    15           {}    False
# 4       0.00    15           {}    False
# ..       ...   ...          ...      ...
# 235      NaN    15           {}    False
# 236      NaN    15           {}    False
# 237      NaN    19           {}    False
# 238      NaN    15           {}    False
# 239      NaN     7           {}    False
#
# [240 rows x 22 columns]

# %%
len(get_distances(data))
# Out:
# 240

# %%
df_stations['distance_to_supersim'] = get_distances(data)

# %%
df_stations.sort_values(by = 'distance_to_supersim', ascending = True)
# Out:
#                                    id                          name  \
# 163  af172dc3045f2f2730d3959b34d17b75       56 - Henrique Schaumann
# 238  ff724047677a832632b2ec87805270c0  215 - E.E. Godofredo Furtado
# 43   30281ec20f9f0d4ba1c5a12021a92f3b        222 - Rua Horácio Lane
# 179  baa6c2785d8b8bc50181c7ee5051c3db      219 - R. Joaquim Antunes
# 42   2f99b00ceacd95133db79cdaa22072a8          216 - João Moura 328
# ..                                ...                           ...
# 176  b856bb9abec5cc4da18b06f51a159d7b             477 - Rua Arizona
# 198  d4ac3e3a43612ad25c40e475f06f5e1a          333 - Rua Flórida 53
# 122  839b5b7c69c403d75fbdd0a99f5f685d   339 - R. Min. Luiz Gallotti
# 89   6197cbb5cb8c87be28262b1df4564f19               311 - Luis Góis
# 234  fc3ce29e4cbee5e7185f3b528b4dd1bc                Base - Batatão
#
#       latitude  longitude                          timestamp  free_bikes  \
# 163 -23.557886 -46.681845  2025-08-17T20:00:25.506318+00:00Z           2
# 238 -23.559442 -46.678456  2025-08-17T20:00:25.505348+00:00Z           1
# 43  -23.558739 -46.687131  2025-08-17T20:00:25.505398+00:00Z           0
# 179 -23.562392 -46.682927  2025-08-17T20:00:25.505372+00:00Z           3
# 42  -23.562142 -46.676536  2025-08-17T20:00:25.505360+00:00Z           4
# ..         ...        ...                                ...         ...
# 176 -23.614898 -46.687426  2025-08-17T20:00:25.505665+00:00Z           7
# 198 -23.617014 -46.681398  2025-08-17T20:00:25.505909+00:00Z           8
# 122 -23.618814 -46.683919  2025-08-17T20:00:25.505959+00:00Z           3
# 89  -23.604226 -46.636996  2025-08-17T20:00:25.506382+00:00Z           3
# 234   0.000000   0.000000  2025-08-17T20:00:25.506940+00:00Z         198
#
#      empty_slots  uid  renting  returning  ...  has_ebikes ebikes  \
# 163            9  458        1          1  ...        True      0
# 238           14  215        1          1  ...        True      0
# 43            15  222        1          1  ...        True      0
# 179           12  219        1          1  ...        True      0
# 42            11  216        1          1  ...        True      0
# ..           ...  ...      ...        ...  ...         ...    ...
# 176           12  280        1          1  ...        True      0
# 198            7  333        1          1  ...        True      0
# 122           24  339        1          1  ...        True      0
# 89            12  469        1          1  ...        True      0
# 234           99  622        1          1  ...        True     99
#
#     normal_bikes                                payment  payment-terminal  \
# 163            2              [key, transitcard, phone]             False
# 238            1  [key, transitcard, creditcard, phone]              True
# 43             0              [key, transitcard, phone]             False
# 179            3              [key, transitcard, phone]             False
# 42             4  [key, transitcard, creditcard, phone]              True
# ..           ...                                    ...               ...
# 176            7              [key, transitcard, phone]             False
# 198            8              [key, transitcard, phone]             False
# 122            3              [key, transitcard, phone]             False
# 89             3  [key, transitcard, creditcard, phone]              True
# 234           99                                    NaN               NaN
#
#      altitude slots rental_uris  virtual  distance_to_supersim
# 163       0.0    11          {}    False              0.139616
# 238       NaN    15          {}    False              0.448757
# 43        NaN    15          {}    False              0.607654
# 179       NaN    15          {}    False              0.650490
# 42        NaN    15          {}    False              0.801168
# ..        ...   ...         ...      ...                   ...
# 176       NaN    19          {}    False              6.479130
# 198       NaN    15          {}    False              6.686471
# 122       NaN    27          {}    False              6.889802
# 89        0.0    15          {}    False              6.966754
# 234       NaN     1          {}    False           5674.275545
#
# [240 rows x 23 columns]

# %%
df_stations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1920 entries, 0 to 1919
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                1920 non-null   object
#  1   name              1920 non-null   object
#  2   latitude          1920 non-null   float64
#  3   longitude         1920 non-null   float64
#  4   timestamp         1920 non-null   object
#  5   free_bikes        1920 non-null   int64
#  6   empty_slots       1920 non-null   int64
#  7   uid               1920 non-null   object
#  8   renting           1920 non-null   int64
#  9   returning         1920 non-null   int64
#  10  last_updated      1912 non-null   float64
#  11  address           1912 non-null   object
#  12  post_code         1640 non-null   object
#  13  has_ebikes        1920 non-null   bool
#  14  ebikes            1920 non-null   int64
#  15  normal_bikes      1920 non-null   int64
#  16  payment           1912 non-null   object
#  17  payment-terminal  1912 non-null   object
#  18  altitude          560 non-null    float64
#  19  slots             1920 non-null   int64
#  20  rental_uris       1920 non-null   object
#  21  virtual           1920 non-null   bool
# dtypes: bool(2), float64(4), int64(7), object(9)
# memory usage: 303.9+ KB

# %%
df_stations.columns
# Out:
# Index(['id', 'name', 'latitude', 'longitude', 'timestamp', 'free_bikes',
#        'empty_slots', 'uid', 'renting', 'returning', 'last_updated', 'address',
#        'post_code', 'has_ebikes', 'ebikes', 'normal_bikes', 'payment',
#        'payment-terminal', 'altitude', 'slots', 'rental_uris', 'virtual',
#        'distance_to_supersim'],
#       dtype='object')

# %%
df_stations

# %%
', '.join(df_stations[['id','timestamp','name','free_bikes','empty_slots','slots','distance_to_supersim','renting','returning','has_ebikes','ebikes','normal_bikes','payment','payment-terminal']].columns)
# Out:
# 'id, timestamp, name, free_bikes, empty_slots, slots, distance_to_supersim, renting, returning, has_ebikes, ebikes, normal_bikes, payment, payment-terminal'

# %%
import psycopg2

# %%
# !pip install psycopg2
# Out:
# Collecting psycopg2
#   Downloading psycopg2-2.9.10-cp313-cp313-win_amd64.whl.metadata (4.8 kB)
# Downloading psycopg2-2.9.10-cp313-cp313-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------------------------------------- 2.6/2.6 MB 20.4 MB/s eta 0:00:00
# Installing collected packages: psycopg2
# Successfully installed psycopg2-2.9.10
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
conn = psycopg2.connect("dbname=weather_db user=postgres password=postgres host=localhost")
cur = conn.cursor()

for s in df_stations:
    cur.execute("""
        INSERT INTO bike_stations (id, updated_at, station_name, free_bikes, empty_slots, slots, distance_to_supersim, renting, returning, has_ebikes, ebikes, normal_bikes, payment, payment_terminal)
        VALUES (%s, NOW(), %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
        ON CONFLICT (station_id) DO NOTHING
    """, (s["id"], s["name"], s["free_bikes"], s["empty_slots"], s["slots"], s["distance_to_supersim"], s["renting"], s["returning"], s["has_ebikes"], s["ebikes"], s["normal_bikes"], s["payment"], s["payment_terminal"]))

conn.commit()
cur.close()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[121], line 9
#       2 cur = conn.cursor()
#       4 for s in df_stations:
#       5     cur.execute("""
#       6         INSERT INTO bike_stations (id, updated_at, station_name, free_bikes, empty_slots, slots, distance_to_supersim, renting, returning, has_ebikes, ebikes, normal_bikes, payment, payment_terminal)
#       7         VALUES (%s, NOW(), %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
#       8         ON CONFLICT (station_id) DO NOTHING
# ----> 9     """, (s["id"], s["name"], s["free_bikes"], s["empty_slots"], s["slots"], s["distance_to_supersim"], s["renting"], s["returning"], s["has_ebikes"], s["ebikes"], s["normal_bikes"], s["payment"], s["payment_terminal"]))
#      11 conn.commit()
#      12 cur.close()
#
# TypeError: string indices must be integers, not 'str'

# %%
conn = psycopg2.connect(
    dbname="weather_db",
    user="postgres",
    password="postgres",
    host="localhost",
    port="5432"
)
cur = conn.cursor()

# Insert row by row
insert_query = """
    INSERT INTO public.citybik_log (id, updated_at, station_name, free_bikes, empty_slots, address, distance_to_supersim, renting, "returning", has_ebikes, ebikes, normal_bikes, payment_terminal)
    VALUES (%s, NOW(), %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
    ON CONFLICT DO NOTHING;
"""

for _, row in df_stations[['id','name','free_bikes','empty_slots','address','distance_to_supersim','renting','returning','has_ebikes','ebikes','normal_bikes','payment-terminal']].iterrows():
    cur.execute(insert_query, tuple(row))

conn.commit()
cur.close()
conn.close()

# %%
df_stations
# Out:
#                                    id                              name  \
# 0    0495af0c779f79ebaa01242df456963d                  204 - Consolação
# 1    05ac42b0b09d9dda95118ee7ff00d5bc               150 - Metrô Paraíso
# 2    07e1bc56a4d45c04055860ae39f9322a         7 - Praça Joaquim Roberto
# 3    086f46ad981708395ea90ca6ae362832  434 - Praça Procópio Ferreira II
# 4    0b509d7429586cacb0776fd8b203d61c            443 - Cardoso Melo III
# ..                                ...                               ...
# 235  fd5d8d6dcc34499ffa8ca4db591e8e45           317 - R. Leonardo Nunes
# 236  fdb890213c54ad952730bd9fab78a147                  76 - 8° Batalhão
# 237  fe23e24943b116bf2b7bbfe856292ffa        131 - Ibirapuera Portão 06
# 238  ff724047677a832632b2ec87805270c0      215 - E.E. Godofredo Furtado
# 239  ffb465bbe6bcfa90eeb06be01e8e3753        95 - R. Manoel da Nóbrega
#
#       latitude  longitude                          timestamp  free_bikes  \
# 0   -23.556727 -46.664197  2025-08-17T20:00:25.505310+00:00Z           0
# 1   -23.575386 -46.641375  2025-08-17T20:00:25.504968+00:00Z           0
# 2   -23.572544 -46.693681  2025-08-17T20:00:25.503928+00:00Z          10
# 3   -23.599550 -46.690740  2025-08-17T20:00:25.506774+00:00Z           3
# 4   -23.596440 -46.688550  2025-08-17T20:00:25.506569+00:00Z           0
# ..         ...        ...                                ...         ...
# 235 -23.598733 -46.639103  2025-08-17T20:00:25.505845+00:00Z           1
# 236 -23.574298 -46.654040  2025-08-17T20:00:25.504419+00:00Z           2
# 237 -23.593685 -46.660042  2025-08-17T20:00:25.504800+00:00Z          13
# 238 -23.559442 -46.678456  2025-08-17T20:00:25.505348+00:00Z           1
# 239 -23.568159 -46.648978  2025-08-17T20:00:25.504534+00:00Z           0
#
#      empty_slots  uid  renting  returning  ...  has_ebikes ebikes  \
# 0             19  204        1          1  ...        True      0
# 1             19  150        1          1  ...        True      0
# 2              9    7        1          1  ...        True      0
# 3             12  592        1          1  ...        True      0
# 4             15  556        1          1  ...        True      0
# ..           ...  ...      ...        ...  ...         ...    ...
# 235           14  317        1          1  ...        True      0
# 236           13   76        1          1  ...        True      0
# 237            6  131        1          1  ...        True      0
# 238           14  215        1          1  ...        True      0
# 239            6   95        1          1  ...        True      0
#
#     normal_bikes                                payment  payment-terminal  \
# 0              0              [key, transitcard, phone]             False
# 1              0  [key, transitcard, creditcard, phone]              True
# 2             10              [key, transitcard, phone]             False
# 3              3              [key, transitcard, phone]             False
# 4              0              [key, transitcard, phone]             False
# ..           ...                                    ...               ...
# 235            1  [key, transitcard, creditcard, phone]              True
# 236            2  [key, transitcard, creditcard, phone]              True
# 237           13              [key, transitcard, phone]             False
# 238            1  [key, transitcard, creditcard, phone]              True
# 239            0              [key, transitcard, phone]             False
#
#      altitude slots rental_uris  virtual  distance_to_supersim
# 0      -23.56    19          {}    False              1.780092
# 1         NaN    19          {}    False              4.604427
# 2         NaN    19          {}    False              2.148335
# 3        0.00    15          {}    False              4.842361
# 4        0.00    15          {}    False              4.464039
# ..        ...   ...         ...      ...                   ...
# 235       NaN    15          {}    False              6.370210
# 236       NaN    15          {}    False              3.429161
# 237       NaN    19          {}    False              4.657215
# 238       NaN    15          {}    False              0.448757
# 239       NaN     7          {}    False              3.569477
#
# [240 rows x 23 columns]

# %%
for test in df_stations:
    print(df_stations.loc[test])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[125], line 2
#       1 for test in df_stations:
# ----> 2     print(df_stations.loc[test])
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py:1431, in _LocIndexer._getitem_axis(self, key, axis)
#    1429 # fall thru to straight lookup
#    1430 self._validate_key(key, axis)
# -> 1431 return self._get_label(key, axis=axis)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py:1381, in _LocIndexer._get_label(self, label, axis)
#    1379 def _get_label(self, label, axis: AxisInt):
#    1380     # GH#5567 this will fail if the label is not present in the axis.
# -> 1381     return self.obj.xs(label, axis=axis)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:4301, in NDFrame.xs(self, key, axis, level, drop_level)
#    4299             new_index = index[loc]
#    4300 else:
# -> 4301     loc = index.get_loc(key)
#    4303     if isinstance(loc, np.ndarray):
#    4304         if loc.dtype == np.bool_:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'id'

# %%
from geopy.distance import geodesic

p1 = (-23.5505, -46.6333)
p2 = (-22.9068, -43.1729)
print(geodesic(p1, p2).km)
# Out:
# 361.2608611455548
